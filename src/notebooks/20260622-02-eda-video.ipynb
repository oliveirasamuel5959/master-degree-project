# %%
import os
import sys
import cv2
import numpy as np
import ipywidgets as widgets
import matplotlib.pyplot as plt
import threading
import io

from pathlib import Path
from PIL import Image as PILImage
from IPython.display import Video, display, HTML

from src.data.loaders import DataLoader

# %%
ROOT_DIR = Path.cwd().parent.parent
sys.path.insert(0, str(ROOT_DIR / "src"))

print(ROOT_DIR)
# Out:
# /home/automation/master-degree-project

# %%
OUTPUT_DIR = ROOT_DIR / "outputs" / "notebooks" / "20260622-02-eda-video"
OUTPUT_DIR.mkdir(exist_ok=True)

RLVS_INPUT_DIR = ROOT_DIR / "datasets" / "RLVS" / "Violence"
UCF_CRIME_INPUT_DIR = ROOT_DIR / "datasets" / "UCF_Crime" / "Violence"

RLVS_INPUT_DIR.mkdir(exist_ok=True)
UCF_CRIME_INPUT_DIR.mkdir(exist_ok=True)

# %%
data_loader = DataLoader(dataset_path=RLVS_INPUT_DIR)
video_files = data_loader.get_video_files()

print(f"Found {len(video_files)} video files in {RLVS_INPUT_DIR}")
print(f"Video files: {[video.name for video in video_files]}")
# Out:
# Found 40 video files in /home/automation/master-degree-project/datasets/RLVS/Violence
# Video files: ['V_26.mp4', 'V_19.mp4', 'V_21.mp4', 'V_10.mp4', 'V_13.mp4', 'V_2.mp4', 'V_12.mp4', 'V_39.mp4', 'V_14.mp4', 'V_34.mp4', 'V_38.mp4', 'V_25.mp4', 'V_1.mp4', 'V_4.mp4', 'V_15.mp4', 'V_31.mp4', 'V_6.mp4', 'V_29.mp4', 'V_22.mp4', 'V_17.mp4', 'V_27.mp4', 'V_23.mp4', 'V_33.mp4', 'V_37.mp4', 'V_35.mp4', 'V_11.mp4', 'V_8.mp4', 'V_7.mp4', 'V_3.mp4', 'V_5.mp4', 'V_16.mp4', 'V_28.mp4', 'V_18.mp4', 'V_32.mp4', 'V_30.mp4', 'V_9.mp4', 'V_40.mp4', 'V_20.mp4', 'V_24.mp4', 'V_36.mp4']

# %%
def display_videos_grid(video_files, columns=4):
    html = f"""
    <div style="
        display:grid;
        grid-template-columns:repeat({columns}, 1fr);
        gap:0px;
        align-items:start;
    ">
    """

    for video_path in video_files:
        html += f"""
        <video
            autoplay
            muted
            loop
            playsinline
            controls
            style="
                width:100%;
                display:block;
                margin:0;
                padding:0;
            "
        >
            <source src="{video_path}" type="video/mp4">
        </video>
        """

    html += "</div>"

    display(HTML(html))

# %% [markdown]
# #### Display Real Life Violence Situations Dataset

# %%
display_videos_grid(video_files, columns=10)
# Out:
#     <div style="
#         display:grid;
#         grid-template-columns:repeat(10, 1fr);
#         gap:0px;
#         align-items:start;
#     ">
#
#         <video
#             autoplay
#             muted
#             loop
#             playsinline
#             controls
#             style="
#                 width:100%;
#                 display:block;
#                 margin:0;
#                 padding:0;
#             "
#         >
#             <source src="/home/automation/master-degree-project/datasets/RLVS/Violence/V_26.mp4" type="video/mp4">
#         </video>
#
#         <video
#             autoplay
#             muted
#             loop
#             playsinline
#             controls
#             style="
#                 width:100%;
#                 display:block;
#                 margin:0;
#                 padding:0;
#             "
#         >
#             <source src="/home/automation/master-degree-project/datasets/RLVS/Violence/V_19.mp4" type="video/mp4">
#         </video>
#
#         <video
#             autoplay
#             muted
#             loop
#             playsinline
#             controls
#             style="
#                 width:100%;
#                 display:block;
#                 margin:0;
#                 padding:0;
#             "
#         >
#             <source src="/home/automation/master-degree-project/datasets/RLVS/Violence/V_21.mp4" type="video/mp4">
#         </video>
#
#         <video
#             autoplay
#             muted
#             loop
#             playsinline
#             controls
#             style="
#                 width:100%;
#                 display:block;
#                 margin:0;
#                 padding:0;
#             "
#         >
#             <source src="/home/automation/master-degree-project/datasets/RLVS/Violence/V_10.mp4" type="video/mp4">
#         </video>
#
#         <video
#             autoplay
#             muted
#             loop
#             playsinline
#             controls
#             style="
#                 width:100%;
#                 display:block;
#                 margin:0;
#                 padding:0;
#             "
#         >
#             <source src="/home/automation/master-degree-project/datasets/RLVS/Violence/V_13.mp4" type="video/mp4">
#         </video>
#
#         <video
#             autoplay
#             muted
#             loop
#             playsinline
#             controls
#             style="
#                 width:100%;
#                 display:block;
#                 margin:0;
#                 padding:0;
#             "
#         >
#             <source src="/home/automation/master-degree-project/datasets/RLVS/Violence/V_2.mp4" type="video/mp4">
#         </video>
#
#         <video
#             autoplay
#             muted
#             loop
#             playsinline
#             controls
#             style="
#                 width:100%;
#                 display:block;
#                 margin:0;
#                 padding:0;
#             "
#         >
#             <source src="/home/automation/master-degree-project/datasets/RLVS/Violence/V_12.mp4" type="video/mp4">
#         </video>
#
#         <video
#             autoplay
#             muted
#             loop
#             playsinline
#             controls
#             style="
#                 width:100%;
#                 display:block;
#                 margin:0;
#                 padding:0;
#             "
#         >
#             <source src="/home/automation/master-degree-project/datasets/RLVS/Violence/V_39.mp4" type="video/mp4">
#         </video>
#
#         <video
#             autoplay
#             muted
#             loop
#             playsinline
#             controls
#             style="
#                 width:100%;
#                 display:block;
#                 margin:0;
#                 padding:0;
#             "
#         >
#             <source src="/home/automation/master-degree-project/datasets/RLVS/Violence/V_14.mp4" type="video/mp4">
#         </video>
#
#         <video
#             autoplay
#             muted
#             loop
#             playsinline
#             controls
#             style="
#                 width:100%;
#                 display:block;
#                 margin:0;
#                 padding:0;
#             "
#         >
#             <source src="/home/automation/master-degree-project/datasets/RLVS/Violence/V_34.mp4" type="video/mp4">
#         </video>
#
#         <video
#             autoplay
#             muted
#             loop
#             playsinline
#             controls
#             style="
#                 width:100%;
#                 display:block;
#                 margin:0;
#                 padding:0;
#             "
#         >
#             <source src="/home/automation/master-degree-project/datasets/RLVS/Violence/V_38.mp4" type="video/mp4">
#         </video>
#
#         <video
#             autoplay
#             muted
#             loop
#             playsinline
#             controls
#             style="
#                 width:100%;
#                 display:block;
#                 margin:0;
#                 padding:0;
#             "
#         >
#             <source src="/home/automation/master-degree-project/datasets/RLVS/Violence/V_25.mp4" type="video/mp4">
#         </video>
#
#         <video
#             autoplay
#             muted
#             loop
#             playsinline
#             controls
#             style="
#                 width:100%;
#                 display:block;
#                 margin:0;
#                 padding:0;
#             "
#         >
#             <source src="/home/automation/master-degree-project/datasets/RLVS/Violence/V_1.mp4" type="video/mp4">
#         </video>
#
#         <video
#             autoplay
#             muted
#             loop
#             playsinline
#             controls
#             style="
#                 width:100%;
#                 display:block;
#                 margin:0;
#                 padding:0;
#             "
#         >
#             <source src="/home/automation/master-degree-project/datasets/RLVS/Violence/V_4.mp4" type="video/mp4">
#         </video>
#
#         <video
#             autoplay
#             muted
#             loop
#             playsinline
#             controls
#             style="
#                 width:100%;
#                 display:block;
#                 margin:0;
#                 padding:0;
#             "
#         >
#             <source src="/home/automation/master-degree-project/datasets/RLVS/Violence/V_15.mp4" type="video/mp4">
#         </video>
#
#         <video
#             autoplay
#             muted
#             loop
#             playsinline
#             controls
#             style="
#                 width:100%;
#                 display:block;
#                 margin:0;
#                 padding:0;
#             "
#         >
#             <source src="/home/automation/master-degree-project/datasets/RLVS/Violence/V_31.mp4" type="video/mp4">
#         </video>
#
#         <video
#             autoplay
#             muted
#             loop
#             playsinline
#             controls
#             style="
#                 width:100%;
#                 display:block;
#                 margin:0;
#                 padding:0;
#             "
#         >
#             <source src="/home/automation/master-degree-project/datasets/RLVS/Violence/V_6.mp4" type="video/mp4">
#         </video>
#
#         <video
#             autoplay
#             muted
#             loop
#             playsinline
#             controls
#             style="
#                 width:100%;
#                 display:block;
#                 margin:0;
#                 padding:0;
#             "
#         >
#             <source src="/home/automation/master-degree-project/datasets/RLVS/Violence/V_29.mp4" type="video/mp4">
#         </video>
#
#         <video
#             autoplay
#             muted
#             loop
#             playsinline
#             controls
#             style="
#                 width:100%;
#                 display:block;
#                 margin:0;
#                 padding:0;
#             "
#         >
#             <source src="/home/automation/master-degree-project/datasets/RLVS/Violence/V_22.mp4" type="video/mp4">
#         </video>
#
#         <video

# %% [markdown]
# #### Display UCF Crime Dataset
